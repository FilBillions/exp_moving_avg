# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='SPY_1d_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 963
# --------------------------------------------------
# 90% Confidence Interval: (4.6812, 6.6527)
# 95% Confidence Interval: (4.4924, 6.8415)
# 98% Confidence Interval: (4.2728, 7.0611)
# 99% Confidence Interval: (4.2728, 7.0611)
# --------------------------------------------------
# Model Results:
# Model Mean: 5.67%
# Model Std: 18.6%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 10.19%
# Buy/Hold Std: 16.33%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 963
# --------------------------------------------------
# 90% Confidence Interval: (0.5266, 0.6474)
# 95% Confidence Interval: (0.515, 0.659)
# 98% Confidence Interval: (0.5015, 0.6725)
# 99% Confidence Interval: (0.5015, 0.6725)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.587
# Model Std: 1.1403
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.869
# Buy/Hold Std: 0.9217
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is down
# --------------------------------------------------
# --------------------------------------------------
# n = 185
# --------------------------------------------------
# 90% Confidence Interval: (3.7127, 8.2837)
# 95% Confidence Interval: (3.2749, 8.7215)
# 98% Confidence Interval: (2.7658, 9.2306)
# 99% Confidence Interval: (2.7658, 9.2306)
# --------------------------------------------------
# Model Results:
# Model Mean: 6.0%
# Model Std: 18.9%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -16.25%
# Buy/Hold Std: 11.64%
# --------------------------------------------------
# --------------------------------------------------
# n = 185
# --------------------------------------------------
# 90% Confidence Interval: (0.1677, 0.3846)
# 95% Confidence Interval: (0.1469, 0.4053)
# 98% Confidence Interval: (0.1228, 0.4295)
# 99% Confidence Interval: (0.1228, 0.4295)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.2761
# Model Std: 0.8966
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.5255
# Buy/Hold Std: 0.3751
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is up
# --------------------------------------------------
# --------------------------------------------------
# n = 778
# --------------------------------------------------
# 90% Confidence Interval: (4.4951, 6.6813)
# 95% Confidence Interval: (4.2857, 6.8907)
# 98% Confidence Interval: (4.0422, 7.1341)
# 99% Confidence Interval: (4.0422, 7.1341)
# --------------------------------------------------
# Model Results:
# Model Mean: 5.59%
# Model Std: 18.54%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 16.48%
# Buy/Hold Std: 9.6%
# --------------------------------------------------
# --------------------------------------------------
# n = 778
# --------------------------------------------------
# 90% Confidence Interval: (0.5914, 0.7305)
# 95% Confidence Interval: (0.578, 0.7438)
# 98% Confidence Interval: (0.5626, 0.7593)
# 99% Confidence Interval: (0.5626, 0.7593)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.6609
# Model Std: 1.1794
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.2006
# Buy/Hold Std: 0.6673
# --------------------------------------------------
